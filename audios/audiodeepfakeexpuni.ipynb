# %%
data_path="for-rerecorded/training"

# %%
import os

# %%
def extract_features(file_path, mfcc=True, chroma=True, mel=True):
    audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
    features = []
    if mfcc:
        mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=13), axis=1)
        features.extend(mfccs)
    if chroma:
        chroma = np.mean(librosa.feature.chroma_stft(y=audio, sr=sample_rate), axis=1)
        features.extend(chroma)
    if mel:
        mel = np.mean(librosa.feature.melspectrogram(y=audio, sr=sample_rate), axis=1)
        features.extend(mel)
    return features

# %%
import librosa
import numpy as np

# %%
def preprocess_dataset(data_path, labels):
    X = []
    y = []
    for label, folder in enumerate(labels):
        for filename in os.listdir(os.path.join(data_path, folder)):
            file_path = os.path.join(data_path, folder, filename)
            features = extract_features(file_path)
            X.append(features)
            y.append(label)
    return np.array(X), np.array(y)

# %%
labels = ["fake", "real"]

# %%
X, y = preprocess_dataset(data_path, labels)

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(y)
y = lb.transform(y)
y = y.ravel()
print(y)
# Out:
# [0 0 0 ... 1 1 1]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=20,shuffle=True, random_state=1)


print("KFold splits: " + str(kf.get_n_splits(X)))
# Out:
# KFold splits: 20

# %%
import pandas as pd

# %%
df=pd.DataFrame(X)

# %%
df
# Out:
#               0           1          2          3          4          5    \
# 0     -174.739410  149.674957   4.881085  27.160982 -24.967499  13.991072
# 1     -152.178223  157.751358  -7.193079  25.628414 -11.556658   8.748322
# 2     -179.938049  146.828873   9.030097  35.061207 -10.734324  25.595644
# 3     -188.319366  122.357864  12.016122  45.064774 -10.562499  22.226219
# 4     -209.632187  147.403030   9.368010  50.477673  -9.735914  22.027719
# ...           ...         ...        ...        ...        ...        ...
# 10203 -238.591690  173.822800  10.715055  25.958763 -20.301331  18.219460
# 10204 -197.566010  103.793015 -12.721643  46.791859 -41.127354  35.025249
# 10205 -167.089218  127.497665 -45.335808  64.245201 -65.533997  49.812309
# 10206 -241.339706  137.626709   0.025781  37.176109 -45.809105  11.524055
# 10207 -227.611465  150.702530  -6.507615  50.950508 -16.925842   5.312900
#
#              6          7          8          9    ...           143  \
# 0      -6.967413 -13.227630  -4.476841 -29.154615  ...  1.591820e-06
# 1     -13.268344 -14.076997  -9.530208 -27.174404  ...  3.866787e-07
# 2     -20.929335 -11.866779  -5.875903 -23.736719  ...  3.173091e-06
# 3     -16.581192  -6.008571  -2.609559 -25.168190  ...  5.313674e-06
# 4     -13.756542  -4.374958  -1.857701 -22.561447  ...  5.889156e-06
# ...          ...        ...        ...        ...  ...           ...
# 10203 -13.657253  -6.645621  -7.487351 -25.430511  ...  8.796574e-07
# 10204 -23.492632 -15.093642   5.178831 -29.095663  ...  5.990125e-05
# 10205 -20.352291  -1.899531   1.235591 -26.864250  ...  1.012643e-05
# 10206 -27.977697 -17.065212   1.126157 -22.746202  ...  4.253087e-06
# 10207  -0.343306 -13.137683 -11.844741 -24.119598  ...  4.719584e-06
#
#                 144           145           146           147           148  \
# 0      1.501739e-06  1.426454e-06  1.366229e-06  1.315959e-06  1.274486e-06
# 1      3.608966e-07  3.396888e-07  3.227526e-07  3.088047e-07  2.975252e-07
# 2      2.952875e-06  2.773992e-06  2.633225e-06  2.517723e-06  2.423770e-06
# %%
from sklearn.neural_network import MLPClassifier

# %%
clf2=MLPClassifier()

# %%
clf2.fit(X_train,y_train)
# Out:
# MLPClassifier()

# %%
clf2.score(X_train,y_train)
# Out:
# 0.9640478056426333

# %%
clf2.score(X_test,y_test)
# Out:
# 0.9322638146167558

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf3=DecisionTreeClassifier()

# %%
clf3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf3.score(X_train,y_train)
# Out:
# 1.0

# %%
clf3.score(X_test,y_test)
# Out:
# 0.8685383244206774

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf4=GradientBoostingClassifier()

# %%
clf4.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
clf4.score(X_train,y_train)
# Out:
# 0.9552311912225705

# %%
clf4.score(X_test,y_test)
# Out:
# 0.9295900178253119

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf5=RandomForestClassifier().fit(X_train,y_train)

# %%
clf5.score(X_train,y_train)
# Out:
# 1.0

# %%
clf5.score(X_test,y_test)
# Out:
# 0.9474153297682709

# %%
from sklearn.ensemble import BaggingClassifier

# %%
clf8=BaggingClassifier().fit(X_train,y_train)

# %%
clf8.score(X_train,y_train)
# Out:
# 0.9959835423197492

# %%
clf8.score(X_test,y_test)
# Out:
# 0.9166666666666666

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
clf9=ExtraTreesClassifier().fit(X_train,y_train)

# %%
clf9.score(X_train,y_train)
# Out:
# 1.0

# %%
clf9.score(X_test,y_test)
# Out:
# 0.9442959001782532

# %%
from sklearn.linear_model import ARDRegression

# %%
clf10=ARDRegression().fit(X_train,y_train)

# %%
clf10.score(X_train,y_train)
# Out:
# 0.20888373497188262

# %%
clf10.score(X_test,y_test)
# Out:
# 0.2264310955709239

# %%
from sklearn.linear_model import LassoLars

# %%
clf11=LassoLars().fit(X_train,y_train)

# %%
clf11.score(X_train,y_train)
# Out:
# 0.32394919036129166

# %%
clf11.score(X_test,y_test)
# Out:
# 0.303671102609378

# %%
from sklearn.linear_model import BayesianRidge

# %%
clf12=BayesianRidge().fit(X_train,y_train)

# %%
clf12.score(X_train,y_train)
# Out:
# 0.5682459050009452

# %%
clf12.score(X_test,y_test)
# Out:
# 0.5394146415387857

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Make predictions on the test set
y_pred = clf1.predict(X_test)

# Convert probabilities to class labels
y_pred_classes = (y_pred > 0.5).astype(int)

# Create a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_classes))
# Out:
# Confusion Matrix:
# [[1099   44]
#  [  39 1062]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      1143
#            1       0.96      0.96      0.96      1101
#
#     accuracy                           0.96      2244
#    macro avg       0.96      0.96      0.96      2244
# weighted avg       0.96      0.96      0.96      2244

# %%
file_path = 'for-rerecorded/training' 
audio_features = extract_features(file_path)

# %%
audio_features
# Out:
# [-433.09164,
#  114.70283,
#  -4.2901425,
#  42.665794,
#  -1.0050657,
#  26.406828,
#  -0.16687989,
#  -5.443137,
#  -17.775555,
#  -15.498422,
#  -6.3406644,
#  -3.3481221,
#  3.9594162,
#  0.46514243,
#  0.40930822,
#  0.38471118,
#  0.30481866,
#  0.30138382,
#  0.45587727,
#  0.4639369,
#  0.49859858,
#  0.4691161,
#  0.4529384,
#  0.39726946,
#  0.43085295,
#  0.0036528416,
#  0.0081720995,
#  0.11260032,
#  1.2847229,
#  5.6107454,
#  2.680298,
#  1.2997361,
#  2.1827934,
#  2.1269157,
#  2.2760015,
#  0.89660263,
#  1.3573629,
#  1.9848173,
#  1.9348806,
#  1.9827057,
#  1.0319008,
#  1.0026878,
#  0.7532252,
#  1.1135602,
#  0.7703646,
#  0.2737987,
#  0.26682475,
#  0.2545441,
#  0.16744696,
#  0.30978003,
#  0.11673952,
#  0.033139955,
#  0.016130302,
#  0.009352227,
#  0.013990659,
#  0.009826947,
#  0.008063572,
#  0.0121949185,
#  0.03069506,
#  0.09864114,
#  0.0832671,
#  0.115231365,
#  0.060978767,
#  0.030743245,
#  0.056595482,
#  0.049398746,
#  0.024130322,
#  0.028259654,
#  0.04566038,
#  0.04713849,
#  0.029510938,
#  0.024691993,
#  0.04202049,
#  0.06722937,
#  0.02849167,
#  0.024319613,
#  0.022636015,
#  0.025119161,
#  0.016481807,
#  0.014908731,
#  0.014948208,
#  0.012283653,
#  0.012330133,
#  0.0073903473,
#  0.004193727,
#  0.007571181,
#  0.0024698519,
#  0.0029857778,
#  0.0036259755,
#  0.0025692617,
#  0.0059158173,
#  0.004008788,
#  0.0046996903,
#  0.004875012,
#  0.0031627435,
#  0.0030238342,
#  0.0018857974,
#  0.0015549465,
#  0.0022048606,
#  0.0024360064,
#  0.0023139091,
#  0.009461099,
#  0.0013631126,
#  0.0009199969,
#  0.0013803573,
#  0.001368114,
#  0.0016367986,
#  0.0021791335,
#  0.002358744,
#  0.002393626,
#  0.0015139919,
#  0.0011249064,
#  0.00086891756,
#  0.0013860182,
#  0.0035459632,
#  0.008095106,
#  0.010939902,
#  0.0076702056,
#  0.006446284,
#  0.009491022,
#  0.009079839,
#  0.009714192,
#  0.009719937,
#  0.0059790877,
#  0.004683549,
#  0.004452553,
#  0.006638848,
#  0.019782517,
#  0.0040468303,
#  0.004025471,
#  0.0056890845,
#  0.008325608,
#  0.00721581,
#  0.005740106,
#  0.003682026,
#  0.0018366099,
#  0.0010189468,
#  0.00038692015,
#  5.144707e-05,
#  2.092272e-06,
#  7.727907e-09,
#  2.2141572e-12,
#  8.9638437e-13,
#  9.102336e-13,
#  1.1033523e-12,
#  1.4299522e-12,
#  1.0128192e-12,
#  1.2632458e-12,
#  1.7022474e-12,
#  1.3257568e-12,
#  1.491795e-12,
#  1.9745913e-12,
#  1.0520107e-12]

# %%
X_array = np.array(audio_features)

# %%
X_reshaped = X_array.reshape(1, -1)

# %%
y_pred=clf1.predict(X_reshaped)

# %%
y_pred
# Out:
# array([1])

# %%
predicted_labels = lb.inverse_transform(y_pred)

# Print the predictions
print("Predicted Label:", predicted_labels)
# Out:
# Predicted Label: [1]

# %%
if predicted_labels[0] == 1:
    print("The audio is classified as real.")
else:
    print("The audio is classified as fake.")
# Out:
# The audio is classified as real.

# %%
import joblib

# %%
joblib.dump(clf1, 'deepfakevoiceperhistboostinggrediant.h5')
# Out:
# ['deepfakevoiceperhistboostinggrediant.h5']

# %%
model=joblib.load('deepfakevoiceperhistboostinggrediant.h5')

# %%
model
# Out:
# HistGradientBoostingClassifier()

# %%
y_pred=model.predict(X_reshaped)

# %%
y_pred
# Out:
# array([0])
